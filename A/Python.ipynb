# %% [markdown]
# <a href="https://colab.research.google.com/github/JeanCarlosB/A/blob/main/A/Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
# <hr>
# <img src='https://github.com/JeanCarlosB/A/blob/main/python3.png?raw=true' width='800'>
# <h1> ‎ </h1>
# <hr>
# <h1><b>Python</b></h1>
#
# ### **Notebook desenvolvido por: [Jean Carlos Barros da Mata](https://github.com/JeanCarlosB)**
#
# </center>
# <hr>

# %%
print("texto")
print("texto \n aqui") # quebra de linha com \n
print("""texto
aqui
""") # quebra de linha sem \n

print("textos "*3) # imprime o texto X vezes, a última plavra tem espaço também

print("cancelando o /n ", end='') #curiosidade não sei se tem utilidade
print("automatico")
# Out:
# texto
# texto
#  aqui
# texto
# aqui
#
# textos textos textos
# cancelando o /n automatico

# %% [markdown]
# ---

# %%
palavra = "animais"

print(palavra)
print(palavra[0] + palavra[1]) #letras das palavras - o começo é zero
print(palavra[:2]) # == [0:2] letras de 0 até antes de 2 - outra forma de fazer a mesma coisa
print(palavra[3:5]) # letras de 3 até antes de 5
print(palavra[-1]) # ordem oposta
print(palavra[-2:]) # letras de -2 até o final

print(palavra.upper()) # torna a palavra em maiuscula
print(palavra.upper().lower()) # minuscula
# Out:
# animais
# an
# an
# ma
# s
# is
# ANIMAIS
# animais

# %% [markdown]
# ---

# %%
frase = "plutão não é planeta"
data = '02/04/2024'

print(frase.split()) # divide por espaço
print(data.split('/')) # divide por /
dia, mes, ano = data.split('/') # separando em outras três variáveis
print("dia",dia)

print("dia", dia, "do mês", mes, "do ano", ano)
print("dia {0} do mês {1} do ano {2}".format(dia,mes,ano)) #veja que não foi retirado o 0 do dia ou mês
# Out:
# ['plutão', 'não', 'é', 'planeta']
# ['02', '04', '2024']
# dia 02
# dia 02 do mês 04 do ano 2024
# dia 02 do mês 04 do ano 2024

# %% [markdown]
# ---

# %%
ban = "banana"
alfa = "alface"

print("eu gosto de {}".format(ban) + 's')
print("eu gosto de",ban + 's')

print("Eu nunca curti",alfa,"porque",ban,"é muito melhor do que",alfa)

print("""Eu nunca curti {0}
porque {1} é muito melhor do que
{0}""".format(alfa,ban))

generica = "eu gosto de {}".format(alfa) + 's' # criando uma nova variavel ao inves de imprimir diretamente
print(generica)

print(len(palavra)) #tamanho de algo
print(len(ban)) # utilizando variaveis
print(len(ban + alfa))
# Out:
# eu gosto de bananas
# eu gosto de bananas
# Eu nunca curti alface porque banana é muito melhor do que alface
# Eu nunca curti alface
# porque banana é muito melhor do que
# alface
# eu gosto de alfaces
# 7
# 6
# 12

# %% [markdown]
# ---

# %%
def impressao_bonita(text):
    print("=" * 40)
    print(f"{text:^40}") #modifica a posição da impressão nesse caso está +- no meio
    print("=" * 40)

nome ="João"
texto_qualquer="Olá {}!".format(nome)
impressao_bonita(texto_qualquer)
# Out:
# ...
#                Olá João!
# ...

# %% [markdown]
# ---

# %%
help(print) #função que explica outras funções 😁
help(round)
print("="*10,"\n",round(2.39,1))
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.
#
# Help on built-in function round in module builtins:
#
# round(number, ndigits=None)
#     Round a number to a given precision in decimal digits.
#
#     The return value is an integer if ndigits is omitted or None.  Otherwise
#     the return value has the same type as the number.  ndigits may be negative.
#
# ...
#  2.4

# %%
def menor_dif_tres(a,b,c): #criando nossa propria função
    """
    ---

    calcula a dif absoluta entre tres numeros e retorna a menor dif entre eles
    ex:
    menor_dif_tres(30,20,24)
    4

    ---
    """
    d1 = abs(a-b)
    d2 = abs(b-c)
    d3 = abs(c-a)
    return min(d1,d2,d3)

help(menor_dif_tres) # mostra a definição entre "" da nossa função
print(menor_dif_tres(30,20,24))

print(1,2,3)
print (1,2,3, sep= ' ')
print (1,2,3, sep= ',')

def dividapordois(d,n=2):
    "-> divide por dois, e divide por n se for posto uma segunda entrada"
    return d//2

help(dividapordois)

print(dividapordois(50))
print(dividapordois(60,3))
# Out:
# Help on function menor_dif_tres in module __main__:
#
# menor_dif_tres(a, b, c)
#     ---
#
#     calcula a dif absoluta entre tres numeros e retorna a menor dif entre eles
#     ex:
#     menor_dif_tres(30,20,24)
#     4
#
#     ---
#
# 4
# 1 2 3
# 1 2 3
# 1,2,3
# Help on function dividapordois in module __main__:
#
# dividapordois(d, n=2)
#     -> divide por dois, e divide por n se for posto uma segunda entrada
#
# 25
# 30

# %% [markdown]
# ---

# %%
numbers = {'one':1, 'two':2, 'three':3}
print(numbers['two'])
numbers['one']
numbers['eleven'] = 11
print(numbers)

for k in numbers:
    print("{} = {}".format(k, numbers[k]))
# Out:
# 2
# {'one': 1, 'two': 2, 'three': 3, 'eleven': 11}
# one = 1
# two = 2
# three = 3
# eleven = 11

# %% [markdown]
# ---
# # Tabelas
# ---

# %%
import pandas as pd #apelido para a biblioteca
exemplo = pd.read_csv ("https://raw.githubusercontent.com/scadriano/lia1_2024_1/main/Introdu%C3%A7%C3%A3o%20ao%20Python%20com%20GitHub%20-%20Colab/hospital.txt")
exemplo
# Out:
#       Id     Nome  Idade Sexo  Peso       Manchas  Temp  Internação Estado  \
# 0   4201     João     55    M  90.0  Concentradas  38.0           2     SP
# 1   3217    Maria     56    F  91.0  Inexistentes  39.5           4     MG
# 2   4039     Luiz     49    M  92.0    Espalhadas  38.0           2     RS
# 3   1920     José     57    M  93.0  Inexistentes  38.5           2     MG
# 4   4340  Cláudia     21    F  52.0     Uniformes  37.6           1     PE
# 5   2301      Ana     58    F  94.0  Inexistentes  38.0           3     RJ
# 6   1322    Marta     19    F  87.0    Espalhadas  39.0           3     AM
# 7   3027    Paulo     34    M  67.0     Uniformes  38.4           2     GO
# 8   3546  Roberto     44    M   NaN     Uniformes  37.6           1     PE
# 9   6754   Lorena     33    F  72.0  Inexistentes  38.0           3     RJ
# 10  1735    Pedro     13    M  87.0    Espalhadas   6.0           4     AM
# ...

# %%
exemplo.describe()
# Out:
#                 Id      Idade       Peso       Temp  Internação
# count    14.000000  14.000000  12.000000  14.000000   14.000000
# mean   3832.428571  39.285714  80.916667  36.035714    2.500000
# std    2206.961110  17.656677  13.500561   8.666346    1.019049
# min    1322.000000  13.000000  52.000000   6.000000    1.000000
# 25%    2482.500000  22.750000  70.750000  38.000000    2.000000
# 50%    3381.500000  39.000000  87.000000  38.000000    2.000000
# 75%    4201.000000  55.750000  91.250000  38.475000    3.000000
# max    9834.000000  65.000000  94.000000  39.500000    4.000000

# %%
exemplo.loc[0] # pega uma linha
# Out:
# Id                     4201
# Nome                   João
# Idade                    55
# Sexo                      M
# Peso                   90.0
# Manchas        Concentradas
# Temp                   38.0
# Internação                2
# Estado                   SP
# Time              Palmeiras
# Diagnóstico          Doente
# Name: 0, dtype: object

# %%
exemplo.loc[3:5] # multiplas linhas
# Out:
#      Id     Nome  Idade Sexo  Peso       Manchas  Temp  Internação Estado  \
# 3  1920     José     57    M  93.0  Inexistentes  38.5           2     MG
# 4  4340  Cláudia     21    F  52.0     Uniformes  37.6           1     PE
# 5  2301      Ana     58    F  94.0  Inexistentes  38.0           3     RJ
#
#        Time Diagnóstico
# 3  Atlético      Doente
# 4     Sport    Saudável
# 5  Botafogo      Doente

# %%
pedaco = exemplo[['Idade','Sexo']]
pedaco
# Out:
#     Idade Sexo
# 0      55    M
# 1      56    F
# 2      49    M
# 3      57    M
# 4      21    F
# 5      58    F
# 6      19    F
# 7      34    M
# 8      44    M
# 9      33    F
# 10     13    M
# 11     65    F
# 12     28    M
# 13     18    F

# %%
exemplo.loc[exemplo['Sexo'] == 'F',['Nome','Idade','Sexo','Peso']] # todas as linhas com o Sexo F mas capenas 4 colunas escolhidas serão mostradas
# Out:
#        Nome  Idade Sexo  Peso
# 1     Maria     56    F  91.0
# 4   Cláudia     21    F  52.0
# 5       Ana     58    F  94.0
# 6     Marta     19    F  87.0
# 9    Lorena     33    F  72.0
# 11    Laura     65    F   NaN
# 13    Maria     18    F  67.0

# %%
exemplo.loc[exemplo['Idade'] > 50] # pessoas com 50 anos ou mais
# Out:
#       Id   Nome  Idade Sexo  Peso       Manchas  Temp  Internação Estado  \
# 0   4201   João     55    M  90.0  Concentradas  38.0           2     SP
# 1   3217  Maria     56    F  91.0  Inexistentes  39.5           4     MG
# 3   1920   José     57    M  93.0  Inexistentes  38.5           2     MG
# 5   2301    Ana     58    F  94.0  Inexistentes  38.0           3     RJ
# 11  9834  Laura     65    F   NaN     Uniformes  38.4           2     GO
#
#          Time Diagnóstico
# 0   Palmeiras      Doente
# 1    Cruzeiro      Doente
# 3    Atlético      Doente
# 5    Botafogo      Doente
# 11  Vila Nova    Saudável

# %% [markdown]
# ---
